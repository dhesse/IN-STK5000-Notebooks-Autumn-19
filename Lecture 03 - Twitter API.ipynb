# %%
import requests
import requests_oauthlib

# %%
from donthackme import CONSUMER_KEY, CONSUMER_SECRET, TOKEN, TOKEN_SECRET

# %%
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
auth = requests_oauthlib.OAuth1(CONSUMER_KEY, CONSUMER_SECRET,
                                TOKEN, TOKEN_SECRET)
verify_response = requests.get(url, auth=auth)

# %%
verify_response
# Out:
# <Response [200]>

# %%
verify_response.json()['name']
# Out:
# 'Dirk Hesse'

# %%
verify_response.json()['screen_name']
# Out:
# 'NotDirkHesse'

# %%
search_url = 'https://api.twitter.com/1.1/search/tweets.json'

# %%
params = {'q': 'data science', 'result_type': 'recent'}

# %%
search_response = requests.get(search_url, params=params, auth=auth)

# %%
search_response
# Out:
# <Response [200]>

# %%
search_response.json().keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
type(search_response.json().get('statuses'))
# Out:
# list

# %%
search_response.json()
# Out:
# {'statuses': [{'created_at': 'Thu Sep 26 07:55:06 +0000 2019',
#    'id': 1177129453261971456,
#    'id_str': '1177129453261971456',
#    'text': 'RT @DataScientistsF: 39.1%+ growth for Deep Learning Chipset Market Size to reach 6310 million USD by 2024\n#ML #MachineLearning #BigData #l…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ML', 'indices': [107, 110]},
#      {'text': 'MachineLearning', 'indices': [111, 127]},
#      {'text': 'BigData', 'indices': [128, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DataScientistsF',
#       'name': 'Data Scientists',
#       'id': 1270025862,
#       'id_str': '1270025862',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.gamer-geek-news.com" rel="nofollow">GGN_RPiTwitterFeed</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 316331833,
#     'id_str': '316331833',
#     'name': 'Gamer Geek',
#     'screen_name': 'GamerGeekNews',
#     'location': '',
#     'description': 'Data Scientist by day, geek tech gamer junky by night.  #PowerBi #Tableau #RaspberryPi  twitter influencer 😜, welcome to my stream of consciousness',
#     'url': 'https://t.co/FKcGDXZxzI',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/FKcGDXZxzI',
#         'expanded_url': 'https://gamer-geek-news.com',
#         'display_url': 'gamer-geek-news.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 12301,
#     'friends_count': 9330,
#     'listed_count': 358,
#     'created_at': 'Mon Jun 13 08:53:46 +0000 2011',
#     'favourites_count': 30095,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 896084,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1404245782/igeek_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1404245782/igeek_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/316331833/1431495420',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 26 07:54:19 +0000 2019',
#     'id': 1177129256834482176,
#     'id_str': '1177129256834482176',
#     'text': '39.1%+ growth for Deep Learning Chipset Market Size to reach 6310 million USD by 2024\n#ML #MachineLearning #BigData… https://t.co/gqzxiCqLU6',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ML', 'indices': [86, 89]},
#       {'text': 'MachineLearning', 'indices': [90, 106]},
#       {'text': 'BigData', 'indices': [107, 115]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/gqzxiCqLU6',
#        'expanded_url': 'https://twitter.com/i/web/status/1177129256834482176',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1270025862,
#      'id_str': '1270025862',
#      'name': 'Data Scientists',
#      'screen_name': 'DataScientistsF',
#      'location': 'Paris, France',
#      'description': '#BigData #DataScience #Analytics #Statistics #PredictiveModeling #ComputerScience #MachineLearning',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2296,
#      'friends_count': 205,
#      'listed_count': 654,
#      'created_at': 'Fri Mar 15 15:52:11 +0000 2013',
#      'favourites_count': 7,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 30030,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/584756954993688576/bce-bDIR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/584756954993688576/bce-bDIR_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1270025862/1428252599',
#      'profile_link_color': '0084B4',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:54:51 +0000 2019',
#    'id': 1177129389542268928,
#    'id_str': '1177129389542268928',
#    'text': 'Get promoted as a product manager by: 1. gaining a deep understanding of customer behavior &amp; 2. lobbying the insigh… https://t.co/Yym8vrBxot',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Yym8vrBxot',
#       'expanded_url': 'https://twitter.com/i/web/status/1177129389542268928',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [121, 144]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 14082276,
#     'id_str': '14082276',
#     'name': 'Claudiu Murariu',
#     'screen_name': 'cllaudiu',
#     'location': 'Brasov, Romania',
#     'description': 'CEO & Co-founder at @innertrends. 500 Startups Alumni. Featured: Entrepreneur, Inc. Proud father of two.',
#     'url': 'http://t.co/nOanafEUxD',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/nOanafEUxD',
#         'expanded_url': 'http://innertrends.com/',
#         'display_url': 'innertrends.com',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 798,
#     'friends_count': 442,
#     'listed_count': 83,
#     'created_at': 'Wed Mar 05 08:29:16 +0000 2008',
#     'favourites_count': 8,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2062,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'AFCBCD',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/2815980103/09bc85560a6af537e51582a10472663e_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2815980103/09bc85560a6af537e51582a10472663e_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14082276/1434363364',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '949CD1',
#     'profile_sidebar_fill_color': 'D2E9F9',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:54:50 +0000 2019',
#    'id': 1177129385876475904,
#    'id_str': '1177129385876475904',
#    'text': '#ProTip \n\nWhen developing #DataScience solutions make sure that you are addressing a real #business problem.\nBuildi… https://t.co/PjNoBTJZya',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ProTip', 'indices': [0, 7]},
#      {'text': 'DataScience', 'indices': [26, 38]},
#      {'text': 'business', 'indices': [90, 99]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/PjNoBTJZya',
#       'expanded_url': 'https://twitter.com/i/web/status/1177129385876475904',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.socialoomph.com" rel="nofollow">SocialOomph</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 948867833433329664,
#     'id_str': '948867833433329664',
#     'name': 'neptune.ml',
#     'screen_name': 'NeptuneML',
#     'location': 'Warszawa, Polska',
#     'description': 'https://t.co/DBpIzkVdOz is a #DataScience collaboration hub. \n\nWe tweet about #MachineLearning best practices and some other cool stuff.',
#     'url': 'https://t.co/lbfF4gBHOy',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/lbfF4gBHOy',
#         'expanded_url': 'http://www.neptune.ml',
#         'display_url': 'neptune.ml',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DBpIzkVdOz',
#         'expanded_url': 'http://neptune.ml',
#         'display_url': 'neptune.ml',
#         'indices': [0, 23]}]}},
#     'protected': False,
#     'followers_count': 808,
#     'friends_count': 913,
#     'listed_count': 14,
#     'created_at': 'Thu Jan 04 10:44:55 +0000 2018',
#     'favourites_count': 334,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2037,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1105454108021047304/XY7uLttQ_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105454108021047304/XY7uLttQ_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/948867833433329664/1555502592',
#     'profile_link_color': '39B1C6',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:54:44 +0000 2019',
#    'id': 1177129360274251776,
#    'id_str': '1177129360274251776',
#    'text': '@DougSt3v3ns @jamisings @LiveVaxFree @misinfofox @Rosewind2007 @silversynergy @ianfmusgrave @TakeThatCDC @ktibus… https://t.co/n1gjULdj8n',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DougSt3v3ns',
#       'name': 'Doug Stevens',
#       'id': 910829124,
#       'id_str': '910829124',
#       'indices': [0, 12]},
#      {'screen_name': 'jamisings',
#       'name': 'Jami says, "REAL loving parents vaccinate!"',
#       'id': 95538410,
#       'id_str': '95538410',
#       'indices': [13, 23]},
#      {'screen_name': 'LiveVaxFree',
#       'name': 'Tiffany M',
#       'id': 3837662720,
#       'id_str': '3837662720',
#       'indices': [24, 36]},
#      {'screen_name': 'misinfofox',
#       'name': 'Marion Blam',
#       'id': 784429922026676224,
#       'id_str': '784429922026676224',
#       'indices': [37, 48]},
#      {'screen_name': 'Rosewind2007',
#       'name': 'Rosewind',
#       'id': 827119753537937408,
#       'id_str': '827119753537937408',
#       'indices': [49, 62]},
#      {'screen_name': 'silversynergy',
#       'name': 'silversynergy',
#       'id': 1110192643,
#       'id_str': '1110192643',
#       'indices': [63, 77]},
#      {'screen_name': 'ianfmusgrave',
#       'name': '💧 Ian Musgrave',
#       'id': 53609015,
#       'id_str': '53609015',
#       'indices': [78, 91]},
#      {'screen_name': 'TakeThatCDC',
#       'name': 'James V. Kohlrabi',
#       'id': 873535798066499586,
#       'id_str': '873535798066499586',
#       'indices': [92, 104]},
#      {'screen_name': 'ktibus',
#       'name': 'Dr KayRay',
#       'id': 195251002,
#       'id_str': '195251002',
#       'indices': [105, 112]}],
#     'urls': [{'url': 'https://t.co/n1gjULdj8n',
#       'expanded_url': 'https://twitter.com/i/web/status/1177129360274251776',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1177124387218173953,
#    'in_reply_to_status_id_str': '1177124387218173953',
#    'in_reply_to_user_id': 910829124,
#    'in_reply_to_user_id_str': '910829124',
#    'in_reply_to_screen_name': 'DougSt3v3ns',
#    'user': {'id': 623732328,
#     'id_str': '623732328',
#     'name': 'Miguel Coyliar',
#     'screen_name': 'Monstercoyliar',
#     'location': 'Diggers Rest, Victoria',
#     'description': 'Flogging with wet lettuce for many years. Trying to use my wits for good and not evil. People, united, we change the world for the better. Resist. Resiliently.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2438,
#     'friends_count': 2831,
#     'listed_count': 10,
#     'created_at': 'Sun Jul 01 11:13:48 +0000 2012',
#     'favourites_count': 177681,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 73316,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1003833573512658944/lW10GGbX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1003833573512658944/lW10GGbX_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:54:42 +0000 2019',
#    'id': 1177129353538416640,
#    'id_str': '1177129353538416640',
#    'text': 'RT @InsectDiversity: Citizen science\nMapping bees, wasps and hornets\nPowerful data\n\nhttps://t.co/qiWV7lHpbI\n#sciku @thescikuproject @entoRa…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'sciku', 'indices': [108, 114]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'InsectDiversity',
#       'name': 'InsectConservation',
#       'id': 2549509836,
#       'id_str': '2549509836',
#       'indices': [3, 19]},
#      {'screen_name': 'thescikuproject',
#       'name': 'The Sciku Project',
#       'id': 848162931162394625,
#       'id_str': '848162931162394625',
#       'indices': [115, 131]}],
#     'urls': [{'url': 'https://t.co/qiWV7lHpbI',
#       'expanded_url': 'https://onlinelibrary.wiley.com/doi/10.1111/icad.12345',
#       'display_url': 'onlinelibrary.wiley.com/doi/10.1111/ic…',
#       'indices': [84, 107]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 103944812,
#     'id_str': '103944812',
#     'name': 'Hymenoptera - NEV',
#     'screen_name': 'hymenoptera_nev',
#     'location': 'The Netherlands',
#     'description': 'The section Hymenoptera of the NEV studies bees, wasps and ants in the Netherlands. R. Broersma en E. vd Spek.',
#     'url': 'http://t.co/6RRH7EEt8K',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/6RRH7EEt8K',
#         'expanded_url': 'http://www.hymenovaria.nl',
#         'display_url': 'hymenovaria.nl',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 975,
#     'friends_count': 134,
#     'listed_count': 55,
#     'created_at': 'Mon Jan 11 19:22:06 +0000 2010',
#     'favourites_count': 7860,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12413,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '352726',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/500956156315987969/KWZooQej_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/500956156315987969/KWZooQej_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/103944812/1408270581',
#     'profile_link_color': 'CC6600',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '99CC33',
#     'profile_text_color': '3E4415',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 26 07:11:05 +0000 2019',
#     'id': 1177118375841058816,
#     'id_str': '1177118375841058816',
#     'text': 'Citizen science\nMapping bees, wasps and hornets\nPowerful data\n\nhttps://t.co/qiWV7lHpbI\n#sciku @thescikuproject… https://t.co/ONFZAAmsIk',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'sciku', 'indices': [87, 93]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'thescikuproject',
#        'name': 'The Sciku Project',
#        'id': 848162931162394625,
#        'id_str': '848162931162394625',
#        'indices': [94, 110]}],
#      'urls': [{'url': 'https://t.co/qiWV7lHpbI',
#        'expanded_url': 'https://onlinelibrary.wiley.com/doi/10.1111/icad.12345',
#        'display_url': 'onlinelibrary.wiley.com/doi/10.1111/ic…',
#        'indices': [63, 86]},
#       {'url': 'https://t.co/ONFZAAmsIk',
#        'expanded_url': 'https://twitter.com/i/web/status/1177118375841058816',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [112, 135]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2549509836,
#      'id_str': '2549509836',
#      'name': 'InsectConservation',
#      'screen_name': 'InsectDiversity',
#      'location': 'St Albans',
#      'description': 'Bringing you the latest news from Insect Conservation & Diversity - content alerts and more',
#      'url': 'http://t.co/MKrFPNkDcI',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/MKrFPNkDcI',
#          'expanded_url': 'http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1752-4598',
#          'display_url': 'onlinelibrary.wiley.com/journal/10.111…',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1997,
#      'friends_count': 166,
#      'listed_count': 50,
#      'created_at': 'Fri Jun 06 08:13:02 +0000 2014',
#      'favourites_count': 1350,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 8405,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/474829091028217856/bhTzLFJ-_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/474829091028217856/bhTzLFJ-_normal.jpeg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2549509836/1402043412',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:54:29 +0000 2019',
#    'id': 1177129296923693061,
#    'id_str': '1177129296923693061',
#    'text': 'RT @Google: “I think of it as the geek’s princess story.” Neha Palmer got into science because of a fascination with Marie Curie. Now she l…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Google',
#       'name': 'Google',
#       'id': 20536157,
#       'id_str': '20536157',
#       'indices': [3, 10]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3595554021,
#     'id_str': '3595554021',
#     'name': 'Tierre Wright',
#     'screen_name': 'TierreWright',
#     'location': '#DMV ',
#     'description': "Watch when you're free! https://t.co/5maiaqhlM6… 🌏🌎🌍 #dcstartupweek #Google",
#     'url': None,
#     'entities': {'description': {'urls': [{'url': 'https://t.co/5maiaqhlM6',
#         'expanded_url': 'http://vimeo.com/233806170/cee8',
#         'display_url': 'vimeo.com/233806170/cee8',
#         'indices': [24, 47]}]}},
#     'protected': False,
#     'followers_count': 508,
#     'friends_count': 222,
#     'listed_count': 69,
#     'created_at': 'Wed Sep 09 06:26:53 +0000 2015',
#     'favourites_count': 3316,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5864,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1166557332521795591/XDDjMsAn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1166557332521795591/XDDjMsAn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3595554021/1549457679',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Sep 24 20:39:01 +0000 2019',
#     'id': 1176596922989199361,
#     'id_str': '1176596922989199361',
#     'text': '“I think of it as the geek’s princess story.” Neha Palmer got into science because of a fascination with Marie Curi… https://t.co/uxVhgK8w0b',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/uxVhgK8w0b',
#        'expanded_url': 'https://twitter.com/i/web/status/1176596922989199361',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 20536157,
#      'id_str': '20536157',
#      'name': 'Google',
#      'screen_name': 'Google',
#      'location': 'Mountain View, CA',
#      'description': '#HeyGoogle',
#      'url': 'https://t.co/ZKjExFWujb',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ZKjExFWujb',
#          'expanded_url': 'http://about.google',
#          'display_url': 'about.google',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 21504109,
#      'friends_count': 214,
#      'listed_count': 109579,
#      'created_at': 'Tue Feb 10 19:14:39 +0000 2009',
#      'favourites_count': 2303,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 102004,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFFFFF',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1057899591708753921/PSpUS-Hp_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1057899591708753921/PSpUS-Hp_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20536157/1560894096',
#      'profile_link_color': '0000CC',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'EBEFF9',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'regular'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 51,
#     'favorite_count': 373,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 51,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:54:19 +0000 2019',
#    'id': 1177129256834482176,
#    'id_str': '1177129256834482176',
#    'text': '39.1%+ growth for Deep Learning Chipset Market Size to reach 6310 million USD by 2024\n#ML #MachineLearning #BigData… https://t.co/gqzxiCqLU6',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ML', 'indices': [86, 89]},
#      {'text': 'MachineLearning', 'indices': [90, 106]},
#      {'text': 'BigData', 'indices': [107, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gqzxiCqLU6',
#       'expanded_url': 'https://twitter.com/i/web/status/1177129256834482176',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1270025862,
#     'id_str': '1270025862',
#     'name': 'Data Scientists',
#     'screen_name': 'DataScientistsF',
#     'location': 'Paris, France',
#     'description': '#BigData #DataScience #Analytics #Statistics #PredictiveModeling #ComputerScience #MachineLearning',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2296,
#     'friends_count': 205,
#     'listed_count': 654,
#     'created_at': 'Fri Mar 15 15:52:11 +0000 2013',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 30030,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/584756954993688576/bce-bDIR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/584756954993688576/bce-bDIR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1270025862/1428252599',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:53:40 +0000 2019',
#    'id': 1177129093193588736,
#    'id_str': '1177129093193588736',
#    'text': 'Data Science is just: see jut cad scans it i.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://www.datascienceisjust.com" rel="nofollow">Data Science is just</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 870860014209998848,
#     'id_str': '870860014209998848',
#     'name': 'datascienceisjust',
#     'screen_name': 'datasciencejust',
#     'location': '',
#     'description': 'Data Science is just...',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 9,
#     'friends_count': 0,
#     'listed_count': 1,
#     'created_at': 'Sat Jun 03 04:29:41 +0000 2017',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 10143,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/870863535877701633/yLDuuqPb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/870863535877701633/yLDuuqPb_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:53:35 +0000 2019',
#    'id': 1177129070661947393,
#    'id_str': '1177129070661947393',
#    'text': 'RT @DataAbz: Next week\'s #Aberdeen Data Meetup.\n\nGreg Fousas of @h2oai  "Any company can be an #AI company" \n\nThen Prof. Not Oren of @aberd…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'Aberdeen', 'indices': [25, 34]},
#      {'text': 'AI', 'indices': [95, 98]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DataAbz',
#       'name': 'Data: Aberdeen',
#       'id': 4863399736,
#       'id_str': '4863399736',
#       'indices': [3, 11]},
#      {'screen_name': 'h2oai',
#       'name': 'H2O.ai',
#       'id': 481867656,
#       'id_str': '481867656',
#       'indices': [64, 70]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 116830375,
#     'id_str': '116830375',
#     'name': 'MBN Solutions',
#     'screen_name': 'mbnsolutions',
#     'location': 'United Kingdom',
#     'description': 'Leading #DataScience #BigData, #Analytics #MachineLearning #Technology #Blockchain #Fintech #Recruitment / #Executive #Search Company. Lastest Jobs - @MBNjobs',
#     'url': 'https://t.co/WabA5XZbGU',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/WabA5XZbGU',
#         'expanded_url': 'http://www.mbnsolutions.com/jobs/',
#         'display_url': 'mbnsolutions.com/jobs/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 8440,
#     'friends_count': 7025,
#     'listed_count': 613,
#     'created_at': 'Tue Feb 23 18:12:31 +0000 2010',
#     'favourites_count': 6916,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 22398,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1153974821467971586/-9ECuWpJ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1153974821467971586/-9ECuWpJ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/116830375/1562767298',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 26 07:36:09 +0000 2019',
#     'id': 1177124686360129537,
#     'id_str': '1177124686360129537',
#     'text': 'Next week\'s #Aberdeen Data Meetup.\n\nGreg Fousas of @h2oai  "Any company can be an #AI company" \n\nThen Prof. Not Ore… https://t.co/XtATTbSa0v',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'Aberdeen', 'indices': [12, 21]},
#       {'text': 'AI', 'indices': [82, 85]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'h2oai',
#        'name': 'H2O.ai',
#        'id': 481867656,
#        'id_str': '481867656',
#        'indices': [51, 57]}],
#      'urls': [{'url': 'https://t.co/XtATTbSa0v',
#        'expanded_url': 'https://twitter.com/i/web/status/1177124686360129537',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4863399736,
#      'id_str': '4863399736',
#      'name': 'Data: Aberdeen',
#      'screen_name': 'DataAbz',
#      'location': 'Aberdeen, Scotland',
#      'description': 'The Aberdeen Data Community',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 430,
#      'friends_count': 471,
#      'listed_count': 7,
#      'created_at': 'Sat Jan 30 10:22:02 +0000 2016',
#      'favourites_count': 1293,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 797,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/962052938179858434/3y-wuyqV_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/962052938179858434/3y-wuyqV_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4863399736/1518206300',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 3,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:53:20 +0000 2019',
#    'id': 1177129009022427136,
#    'id_str': '1177129009022427136',
#    'text': 'RT @DataScienceCtrl: Data Science Lessons from the Apollo Moon Landing https://t.co/UwU3DldXfv',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DataScienceCtrl',
#       'name': 'Data Science Central',
#       'id': 393033324,
#       'id_str': '393033324',
#       'indices': [3, 19]}],
#     'urls': [{'url': 'https://t.co/UwU3DldXfv',
#       'expanded_url': 'https://buff.ly/2ZilEWM',
#       'display_url': 'buff.ly/2ZilEWM',
#       'indices': [71, 94]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://m1.t7w.co" rel="nofollow">T7 App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1085679912252514307,
#     'id_str': '1085679912252514307',
#     'name': 'Jason Abdi',
#     'screen_name': 'jason_abdi',
#     'location': 'Calgary, Alberta',
#     'description': 'Passionate tech leader steering strategic digital transformations that enable quantifiable business results. #CIO #itleadership #cybersecurity #cloud #IT #SaaS',
#     'url': 'https://t.co/IX9MAwP76f',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/IX9MAwP76f',
#         'expanded_url': 'http://www.linkedin.com/in/jasonabdi',
#         'display_url': 'linkedin.com/in/jasonabdi',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 425,
#     'friends_count': 187,
#     'listed_count': 27,
#     'created_at': 'Wed Jan 16 23:27:16 +0000 2019',
#     'favourites_count': 971,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 18767,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1135240691880058880/8WQi-KVL_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1135240691880058880/8WQi-KVL_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1085679912252514307/1548097474',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 26 04:24:22 +0000 2019',
#     'id': 1177076421258334208,
#     'id_str': '1177076421258334208',
#     'text': 'Data Science Lessons from the Apollo Moon Landing https://t.co/UwU3DldXfv',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/UwU3DldXfv',
#        'expanded_url': 'https://buff.ly/2ZilEWM',
#        'display_url': 'buff.ly/2ZilEWM',
#        'indices': [50, 73]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 393033324,
#      'id_str': '393033324',
#      'name': 'Data Science Central',
#      'screen_name': 'DataScienceCtrl',
#      'location': 'Los Angeles, CA',
#      'description': 'Co-founded by Vincent Granville and part the DSC Community, our focus is on data science, ML, AI, deep learning, dataviz, Hadoop, IoT, and BI.',
#      'url': 'http://t.co/gbSIHZcKZR',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/gbSIHZcKZR',
#          'expanded_url': 'http://www.DataScienceCentral.com',
#          'display_url': 'DataScienceCentral.com',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 152210,
#      'friends_count': 1109,
#      'listed_count': 3924,
#      'created_at': 'Mon Oct 17 22:45:52 +0000 2011',
#      'favourites_count': 4588,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 47598,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/823989084699836416/HLeb5i56_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/823989084699836416/HLeb5i56_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/393033324/1488557327',
# ...
#      'url': 'https://t.co/VXkVChNLcT',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/VXkVChNLcT',
#          'expanded_url': 'https://www.linkedin.com/in/harry-butcher-0192b893/',
#          'display_url': 'linkedin.com/in/harry-butch…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 602,
#      'friends_count': 1544,
#      'listed_count': 7,
#      'created_at': 'Fri Sep 09 19:10:49 +0000 2016',
#      'favourites_count': 652,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 777,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1138523047831461893/S2F0SaZy_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138523047831461893/S2F0SaZy_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/774324193928351744/1549542405',
#      'profile_link_color': '010203',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:52:16 +0000 2019',
#    'id': 1177128740435976192,
#    'id_str': '1177128740435976192',
#    'text': '📣We welcome you to participate in Data Science for Business Sector Meetup! \n👨\u200d💻Our special invited speaker from 🇺🇸-… https://t.co/D5P6nMXohI',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/D5P6nMXohI',
#       'expanded_url': 'https://twitter.com/i/web/status/1177128740435976192',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 131031879,
#     'id_str': '131031879',
#     'name': 'U.S. Embassy Bishkek',
#     'screen_name': 'USEmbassyKG',
#     'location': 'Bishkek, Kyrgyz Republic',
#     'description': 'Official Twitter Feed for the Embassy of the United States of America to the Kyrgyz Republic. RT ≠ endorsement. \nhttps://t.co/koh6R7lSRp…',
#     'url': 'https://t.co/RZAaR4LJSY',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/RZAaR4LJSY',
#         'expanded_url': 'https://kg.usembassy.gov',
#         'display_url': 'kg.usembassy.gov',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/koh6R7lSRp',
#         'expanded_url': 'http://facebook.com/usembassy.bish',
#         'display_url': 'facebook.com/usembassy.bish',
#         'indices': [113, 136]}]}},
#     'protected': False,
#     'followers_count': 67948,
#     'friends_count': 683,
#     'listed_count': 264,
#     'created_at': 'Fri Apr 09 02:18:44 +0000 2010',
#     'favourites_count': 1793,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 10892,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '709397',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme6/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1117755950134435841/Z6IElmAh_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1117755950134435841/Z6IElmAh_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/131031879/1568090407',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Thu Sep 26 07:51:54 +0000 2019',
#    'id': 1177128648094212096,
#    'id_str': '1177128648094212096',
#    'text': "RT @HarryButcher8: Great article, Jasmine! \n\n'The Data Science Gender Gap' https://t.co/UCBIS0sJnK",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'HarryButcher8',
#       'name': 'Harry Butcher 🚀',
#       'id': 774324193928351744,
#       'id_str': '774324193928351744',
#       'indices': [3, 17]}],
#     'urls': [{'url': 'https://t.co/UCBIS0sJnK',
#       'expanded_url': 'https://buff.ly/2mqg4zQ',
#       'display_url': 'buff.ly/2mqg4zQ',
#       'indices': [75, 98]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/whtver_science" rel="nofollow">nembotavy_010101</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1049470998490185729,
#     'id_str': '1049470998490185729',
#     'name': 'Ñembotavy',
#     'screen_name': 'nembotavy_0101',
#     'location': '',
#     'description': 'Art, music, politics, history, science, gender, and entrepreneurship. Always learning and hoping to do so, willing to play the fool. I do that well.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4339,
#     'friends_count': 5,
#     'listed_count': 98,
#     'created_at': 'Tue Oct 09 01:25:59 +0000 2018',
#     'favourites_count': 1981,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 373321,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1162639815084404736/GdeIeGLc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1162639815084404736/GdeIeGLc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1049470998490185729/1563955598',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 26 07:51:00 +0000 2019',
#     'id': 1177128422868508673,
#     'id_str': '1177128422868508673',
#     'text': "Great article, Jasmine! \n\n'The Data Science Gender Gap' https://t.co/UCBIS0sJnK",
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/UCBIS0sJnK',
#        'expanded_url': 'https://buff.ly/2mqg4zQ',
#        'display_url': 'buff.ly/2mqg4zQ',
#        'indices': [56, 79]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 774324193928351744,
#      'id_str': '774324193928351744',
#      'name': 'Harry Butcher 🚀',
#      'screen_name': 'HarryButcher8',
#      'location': 'London, England',
#      'description': 'Talent Partner @ DN 👨🏻\u200d💻Rookie Python coder 💻Data Science Enthusiast 📊Bristol/London based 📍',
#      'url': 'https://t.co/VXkVChNLcT',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/VXkVChNLcT',
#          'expanded_url': 'https://www.linkedin.com/in/harry-butcher-0192b893/',
#          'display_url': 'linkedin.com/in/harry-butch…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 602,
#      'friends_count': 1544,
#      'listed_count': 7,
#      'created_at': 'Fri Sep 09 19:10:49 +0000 2016',
#      'favourites_count': 652,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 777,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1138523047831461893/S2F0SaZy_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1138523047831461893/S2F0SaZy_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/774324193928351744/1549542405',
#      'profile_link_color': '010203',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Thu Sep 26 07:51:02 +0000 2019',
#    'id': 1177128429986168834,
#    'id_str': '1177128429986168834',
#    'text': '@Anoop_Odlme @FrancisLallema2 @RetinaScanning @nowthisnews @UKDemockery @AOC School dropouts who pretend to underst… https://t.co/fbVDjhD2ZS',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Anoop_Odlme',
#       'name': 'Lonely impulse of delight.',
#       'id': 125876182,
#       'id_str': '125876182',
#       'indices': [0, 12]},
#      {'screen_name': 'FrancisLallema2',
#       'name': 'Francis Lallemand',
#       'id': 818507858941804547,
#       'id_str': '818507858941804547',
#       'indices': [13, 29]},
#      {'screen_name': 'RetinaScanning',
#       'name': 'Perfide Albion #CrimesOfTheTongue',
#       'id': 606374313,
#       'id_str': '606374313',
#       'indices': [30, 45]},
#      {'screen_name': 'nowthisnews',
#       'name': 'NowThis',
#       'id': 701725963,
#       'id_str': '701725963',
#       'indices': [46, 58]},
#      {'screen_name': 'UKDemockery',
#       'name': 'The Agitator',
#       'id': 734778182105239552,
#       'id_str': '734778182105239552',
#       'indices': [59, 71]},
#      {'screen_name': 'AOC',
#       'name': 'Alexandria Ocasio-Cortez',
#       'id': 138203134,
#       'id_str': '138203134',
#       'indices': [72, 76]}],
#     'urls': [{'url': 'https://t.co/fbVDjhD2ZS',
#       'expanded_url': 'https://twitter.com/i/web/status/1177128429986168834',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1177030711217463298,
#    'in_reply_to_status_id_str': '1177030711217463298',
#    'in_reply_to_user_id': 125876182,
#    'in_reply_to_user_id_str': '125876182',
#    'in_reply_to_screen_name': 'Anoop_Odlme',
#    'user': {'id': 2883444707,
#     'id_str': '2883444707',
#     'name': 'Lvl1 Blood Dragon',
#     'screen_name': 'DudeHazard',
#     'location': "16'45N 78'69W, Twitterspace",
#     'description': 'Back to business !🙃',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 259,
#     'friends_count': 293,
#     'listed_count': 7,
#     'created_at': 'Wed Nov 19 01:21:05 +0000 2014',
#     'favourites_count': 69176,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 28111,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/901297296423440385/-gwocPAM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/901297296423440385/-gwocPAM_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2883444707/1503722031',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.051,
#   'max_id': 1177129453261971456,
#   'max_id_str': '1177129453261971456',
#   'next_results': '?max_id=1177128429986168833&q=data%20science&include_entities=1&result_type=recent',
#   'query': 'data+science',
#   'refresh_url': '?since_id=1177129453261971456&q=data%20science&result_type=recent&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
